# %%
Datset on 2 language with translation

# %%
Maximum size in both languages and fix the input and output size

seq -> when a sentence starts and when a sentence end
fixed input  - 10
fixed output - 5

# %%
Pre processing -

# %%
Padding - > 0 0 0 0

# %%
Seq2Seq

Encoder and Decoder

Encoder takes the input
decoder gives the output

Encoder Group of LSTM - output

Input to the decoder - Decoder predicts the output - till you get end sequence


Input is a sequence of word -> embedding  - 10
LSTM
repeatvector
LSTM
Dense number neuron 5

# %% [markdown]
# # Language Translation with Word Level seq2seq DL Models
#
# The objective is to convert a German sentence (sequence of words) to English using a Neural Machine Translation (NMT) system based on word level encoder-decoder models.
#
# ![](https://i.imgur.com/So32H7U.png)
#
# We will use German-English sentence pairs data from http://www.manythings.org/anki/
#
#
# Sequence-to-Sequence (seq2seq) models are used for a variety of NLP tasks, such as text summarization, speech recognition, language translation, text-to-speech, speech-to-text among others. Our aim is to translate german to english sentences.
#
# Here, both, the input and output are sentences. In other words, these sentences are a sequence of words going in and out of our model.
#
# ![](https://i.imgur.com/Uk1tCPo.png)
#
# A typical seq2seq model is also known as an encoder-decoder model and has 2 major components:
# - The encoder
# - The decoder
#
# Both these parts are essentially two different sequential models like RNNs\LSTMs which are combined together.
#
# ![](https://i.imgur.com/bT6PAtv.png)

# %% [markdown]
# # Download the Dataset

# %%
# !wget http://www.manythings.org/anki/deu-eng.zip
# !unzip deu-eng.zip
# !ls -l
# Out:
# --2026-03-08 05:33:41--  http://www.manythings.org/anki/deu-eng.zip
# Resolving www.manythings.org (www.manythings.org)... 173.254.30.110
# Connecting to www.manythings.org (www.manythings.org)|173.254.30.110|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11856206 (11M) [application/zip]
# Saving to: ‘deu-eng.zip’
#
# deu-eng.zip         100%[===================>]  11.31M  71.6MB/s    in 0.2s
#
# 2026-03-08 05:33:42 (71.6 MB/s) - ‘deu-eng.zip’ saved [11856206/11856206]
#
# Archive:  deu-eng.zip
#   inflating: deu.txt
#   inflating: _about.txt
# total 62136
# -rw-r--r-- 1 root root     1441 Feb 13 06:17 _about.txt
# -rw-r--r-- 1 root root 11856206 Feb 13 00:33 deu-eng.zip
# -rw-r--r-- 1 root root 51760397 Feb 13 06:17 deu.txt
# drwxr-xr-x 1 root root     4096 Feb  6 14:31 sample_data

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)

# %% [markdown]
# # Load up the dataset

# %%
import numpy as np

FILE_NAME = './deu.txt'
with open(FILE_NAME, mode='rt', encoding='utf-8') as infile:
  data = infile.read()
  sentences = data.strip().split('\n')
  sentences = [item.split('\t') for item in sentences]
  eng_deu = np.array(sentences)

eng_deu = eng_deu[:50000]
eng_deu
# Out:
# array([['Go.', 'Geh.',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8597805 (Roujin)'],
#        ['Hi.', 'Hallo!',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #380701 (cburgmer)'],
#        ['Hi.', 'Grüß Gott!',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #659813 (Esperantostern)'],
#        ...,
#        ["We'd better find it.", 'Wir müssen es finden.',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #3439536 (CK) & #3609901 (Jan_Schreiber)'],
#        ["We'd never hurt Tom.", 'Wir täten Tom nie etwas.',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #3921422 (CK) & #6829360 (Pfirsichbaeumchen)'],
#        ["We'll be right back.", 'Wir sind gleich wieder da.',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #3312269 (CK) & #13258499 (Waldelfe)']],
#       dtype='<U537')

# %%
deu = eng_deu[:,1]
eng = eng_deu[:,0]
eng, deu
# Out:
# (array(['Go.', 'Hi.', 'Hi.', ..., "We'd better find it.",
#         "We'd never hurt Tom.", "We'll be right back."], dtype='<U537'),
#  array(['Geh.', 'Hallo!', 'Grüß Gott!', ..., 'Wir müssen es finden.',
#         'Wir täten Tom nie etwas.', 'Wir sind gleich wieder da.'],
#        dtype='<U537'))

# %% [markdown]
# # Basic Text Pre-processing

# %%
import string

# Remove punctuation and lowercase
eng = np.array([s.translate(str.maketrans('', '', string.punctuation)).lower() for s in eng])
deu = np.array([s.translate(str.maketrans('', '', string.punctuation)).lower() for s in deu])
eng, deu
# Out:
# (array(['go', 'hi', 'hi', ..., 'wed better find it', 'wed never hurt tom',
#         'well be right back'], dtype='<U19'),
#  array(['geh', 'hallo', 'grüß gott', ..., 'wir müssen es finden',
#         'wir täten tom nie etwas', 'wir sind gleich wieder da'],
#        dtype='<U71'))

# %% [markdown]
# # Viewing Sentence Lengths

# %%
eng_len = [len(s.split()) for s in eng]
deu_len = [len(s.split()) for s in deu]

max(eng_len), max(deu_len)
# Out:
# (6, 12)

# %%
import pandas as pd
# %matplotlib inline

length_df = pd.DataFrame({'eng':eng_len, 'deu':deu_len})
length_df.hist(bins=30)
# Out:
# array([[<Axes: title={'center': 'eng'}>, <Axes: title={'center': 'deu'}>]],
#       dtype=object)

# %% [markdown]
# # Converting Text to Sequences of Numbers

# %%
from tensorflow import keras

eng_tokenizer = keras.preprocessing.text.Tokenizer()
eng_tokenizer.fit_on_texts(eng)
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max(eng_len)
print('Max eng text length:', eng_length)
print('English Vocabulary Size:', eng_vocab_size)
# Out:
# Max eng text length: 6
# English Vocabulary Size: 6147

# %%
deu_tokenizer = keras.preprocessing.text.Tokenizer()
deu_tokenizer.fit_on_texts(deu)
deu_vocab_size = len(deu_tokenizer.word_index) + 1
deu_length = max(deu_len)
print('Max deu text length:', deu_length)
print('German Vocabulary Size:', deu_vocab_size)
# Out:
# Max deu text length: 12
# German Vocabulary Size: 10131

# %%
from sklearn.model_selection import train_test_split

train_deu, test_deu, train_eng, test_eng = train_test_split(deu, eng, test_size=0.2, random_state = 42)
train_deu.shape, test_deu.shape, train_eng.shape, test_eng.shape
# Out:
# ((40000,), (10000,), (40000,), (10000,))

# %%
train_deu, train_eng
# Out:
# (array(['tom tanzte mit mir', 'tom ist mein schüler',
#         'ich komme bald wieder zurück', ..., 'sehen sie genauer hin',
#         'ich habe ihn verloren', 'verstecken wir uns hier'], dtype='<U71'),
#  array(['tom danced with me', 'tom is my student', 'i will be back soon',
#         ..., 'take a closer look', 'i lost it', 'lets hide here'],
#        dtype='<U19'))

# %% [markdown]
# ### We pad the sequences of texts also to make sure they are of uniform length

# %%
train_deu_enc = deu_tokenizer.texts_to_sequences(train_deu)
train_deu_enc = keras.preprocessing.sequence.pad_sequences(train_deu_enc, maxlen=deu_length, padding='post')

train_eng_enc = eng_tokenizer.texts_to_sequences(train_eng)
train_eng_enc = keras.preprocessing.sequence.pad_sequences(train_eng_enc, maxlen=eng_length, padding='post')

train_deu_enc.shape, train_eng_enc.shape
# Out:
# ((40000, 12), (40000, 6))

# %%
test_deu_enc = deu_tokenizer.texts_to_sequences(test_deu)
test_deu_enc = keras.preprocessing.sequence.pad_sequences(test_deu_enc, maxlen=deu_length, padding='post')

test_eng_enc = eng_tokenizer.texts_to_sequences(test_eng)
test_eng_enc = keras.preprocessing.sequence.pad_sequences(test_eng_enc, maxlen=eng_length, padding='post')

test_deu_enc.shape, test_eng_enc.shape
# Out:
# ((10000, 12), (10000, 6))

# %% [markdown]
# # Build seq2seq Model Architecture
#
# ![](https://i.imgur.com/3ZVi97s.png)
#
# - For the encoder, we will use an embedding layer and an LSTM layer
# - For the decoder, we will use another LSTM layer followed by a dense layer
# - Repeat Vector helps pass the output sequence from encoder to all LSTM cells in the decoder
#
# We leverage the full power of GPUs by using the CUDA variant of the LSTM models.

# %%
EMBEDDING_DIM = 2048
LSTM_UNITS = 1024

encoder_inputs = keras.layers.Input(shape=(deu_length,))
enc_emb =  keras.layers.Embedding(deu_vocab_size, EMBEDDING_DIM)(encoder_inputs)
encoder_lstm = keras.layers.LSTM(LSTM_UNITS)(enc_emb)
rp_vec = keras.layers.RepeatVector(eng_length)(encoder_lstm)

decoder_lstm = keras.layers.LSTM(LSTM_UNITS, return_sequences=True)(rp_vec)
decoder_softmax = keras.layers.Dense(eng_vocab_size, activation='softmax')(decoder_lstm)
model = keras.models.Model(inputs=encoder_inputs, outputs=decoder_softmax)

model.compile(optimizer='adam')
model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 12)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding_6 (Embedding)         │ (None, 12, 2048)       │    20,748,288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_10 (LSTM)                  │ (None, 1024)           │    12,587,008 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ repeat_vector_5 (RepeatVector)  │ (None, 6, 1024)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_11 (LSTM)                  │ (None, 6, 1024)        │     8,392,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 6, 6147)        │     6,300,675 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 48,028,675 (183.21 MB)
#  Trainable params: 48,028,675 (183.21 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Model Training
#
# We save the model with minimum loss here also with checkpointing

# %%
mc = keras.callbacks.ModelCheckpoint('my_nmt_model_min_loss.h5', monitor='val_loss', verbose=1, save_best_only=True, mode='min')

history = model.fit(train_deu_enc, train_eng_enc.reshape(train_eng_enc.shape[0], train_eng_enc.shape[1], 1),
          epochs=50, batch_size=512,
          validation_split = 0.1,
          callbacks=[mc], verbose=1)
# Out:
# W0805 17:28:29.654081 140644815132544 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 36000 samples, validate on 4000 samples
# Epoch 1/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 3.7648
# Epoch 00001: val_loss improved from inf to 3.39901, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 15s 405us/sample - loss: 3.7631 - val_loss: 3.3990
# Epoch 2/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 3.3517
# Epoch 00002: val_loss improved from 3.39901 to 3.35146, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 193us/sample - loss: 3.3515 - val_loss: 3.3515
# Epoch 3/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 3.2656
# Epoch 00003: val_loss improved from 3.35146 to 3.21310, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 196us/sample - loss: 3.2655 - val_loss: 3.2131
# Epoch 4/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 3.1380
# Epoch 00004: val_loss improved from 3.21310 to 3.07847, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 196us/sample - loss: 3.1376 - val_loss: 3.0785
# Epoch 5/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 3.0007
# Epoch 00005: val_loss improved from 3.07847 to 3.04872, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 199us/sample - loss: 3.0004 - val_loss: 3.0487
# Epoch 6/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 2.8831
# Epoch 00006: val_loss improved from 3.04872 to 2.88336, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 201us/sample - loss: 2.8826 - val_loss: 2.8834
# Epoch 7/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 2.7544
# Epoch 00007: val_loss improved from 2.88336 to 2.85535, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 203us/sample - loss: 2.7539 - val_loss: 2.8554
# Epoch 8/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 2.6243
# Epoch 00008: val_loss improved from 2.85535 to 2.66616, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 202us/sample - loss: 2.6243 - val_loss: 2.6662
# Epoch 9/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 2.4882
# Epoch 00009: val_loss improved from 2.66616 to 2.57755, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 200us/sample - loss: 2.4886 - val_loss: 2.5776
# Epoch 10/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 2.3674
# Epoch 00010: val_loss improved from 2.57755 to 2.53446, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 199us/sample - loss: 2.3673 - val_loss: 2.5345
# Epoch 11/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 2.2693
# Epoch 00011: val_loss improved from 2.53446 to 2.43227, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 198us/sample - loss: 2.2695 - val_loss: 2.4323
# Epoch 12/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 2.1713
# Epoch 00012: val_loss improved from 2.43227 to 2.38354, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 197us/sample - loss: 2.1710 - val_loss: 2.3835
# Epoch 13/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 2.0775
# Epoch 00013: val_loss improved from 2.38354 to 2.33745, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 197us/sample - loss: 2.0771 - val_loss: 2.3375
# Epoch 14/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 1.9851
# Epoch 00014: val_loss improved from 2.33745 to 2.25238, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 197us/sample - loss: 1.9844 - val_loss: 2.2524
# Epoch 15/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 1.8871
# Epoch 00015: val_loss improved from 2.25238 to 2.18146, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 197us/sample - loss: 1.8872 - val_loss: 2.1815
# Epoch 16/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 1.7936
# Epoch 00016: val_loss improved from 2.18146 to 2.11613, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 198us/sample - loss: 1.7933 - val_loss: 2.1161
# Epoch 17/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 1.6971
# Epoch 00017: val_loss improved from 2.11613 to 2.07090, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 198us/sample - loss: 1.6973 - val_loss: 2.0709
# Epoch 18/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 1.6081
# Epoch 00018: val_loss improved from 2.07090 to 2.02759, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 199us/sample - loss: 1.6084 - val_loss: 2.0276
# Epoch 19/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 1.5245
# Epoch 00019: val_loss improved from 2.02759 to 1.97895, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 200us/sample - loss: 1.5245 - val_loss: 1.9789
# Epoch 20/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 1.4417
# Epoch 00020: val_loss improved from 1.97895 to 1.96714, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 199us/sample - loss: 1.4415 - val_loss: 1.9671
# Epoch 21/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 1.3613
# Epoch 00021: val_loss improved from 1.96714 to 1.88552, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 199us/sample - loss: 1.3614 - val_loss: 1.8855
# Epoch 22/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 1.2817
# Epoch 00022: val_loss improved from 1.88552 to 1.84159, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 199us/sample - loss: 1.2821 - val_loss: 1.8416
# Epoch 23/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 1.2075
# Epoch 00023: val_loss improved from 1.84159 to 1.83443, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 199us/sample - loss: 1.2078 - val_loss: 1.8344
# Epoch 24/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 1.1343
# Epoch 00024: val_loss improved from 1.83443 to 1.80286, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 199us/sample - loss: 1.1345 - val_loss: 1.8029
# Epoch 25/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 1.0673
# Epoch 00025: val_loss improved from 1.80286 to 1.75995, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 198us/sample - loss: 1.0672 - val_loss: 1.7600
# Epoch 26/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 0.9974
# Epoch 00026: val_loss improved from 1.75995 to 1.74288, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 198us/sample - loss: 0.9974 - val_loss: 1.7429
# Epoch 27/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 0.9330
# Epoch 00027: val_loss improved from 1.74288 to 1.70988, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 198us/sample - loss: 0.9331 - val_loss: 1.7099
# Epoch 28/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 0.8708
# Epoch 00028: val_loss did not improve from 1.70988
# 36000/36000 [==============================] - 7s 194us/sample - loss: 0.8710 - val_loss: 1.7111
# Epoch 29/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 0.8138
# Epoch 00029: val_loss improved from 1.70988 to 1.67615, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 198us/sample - loss: 0.8140 - val_loss: 1.6761
# Epoch 30/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 0.7579
# Epoch 00030: val_loss improved from 1.67615 to 1.65283, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 198us/sample - loss: 0.7582 - val_loss: 1.6528
# Epoch 31/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 0.7043
# Epoch 00031: val_loss improved from 1.65283 to 1.63526, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 198us/sample - loss: 0.7045 - val_loss: 1.6353
# Epoch 32/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 0.6537
# Epoch 00032: val_loss did not improve from 1.63526
# 36000/36000 [==============================] - 7s 194us/sample - loss: 0.6538 - val_loss: 1.6621
# Epoch 33/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 0.6072
# Epoch 00033: val_loss improved from 1.63526 to 1.63259, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 199us/sample - loss: 0.6075 - val_loss: 1.6326
# Epoch 34/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 0.5623
# Epoch 00034: val_loss improved from 1.63259 to 1.61371, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 198us/sample - loss: 0.5624 - val_loss: 1.6137
# Epoch 35/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 0.5195
# Epoch 00035: val_loss did not improve from 1.61371
# 36000/36000 [==============================] - 7s 194us/sample - loss: 0.5197 - val_loss: 1.6296
# Epoch 36/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 0.4812
# Epoch 00036: val_loss did not improve from 1.61371
# 36000/36000 [==============================] - 7s 195us/sample - loss: 0.4814 - val_loss: 1.6190
# Epoch 37/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 0.4438
# Epoch 00037: val_loss improved from 1.61371 to 1.61240, saving model to my_nmt_model_min_loss.h5
# 36000/36000 [==============================] - 7s 199us/sample - loss: 0.4442 - val_loss: 1.6124
# Epoch 38/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 0.4084
# Epoch 00038: val_loss did not improve from 1.61240
# 36000/36000 [==============================] - 7s 195us/sample - loss: 0.4088 - val_loss: 1.6141
# Epoch 39/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 0.3762
# Epoch 00039: val_loss did not improve from 1.61240
# 36000/36000 [==============================] - 7s 195us/sample - loss: 0.3764 - val_loss: 1.6231
# Epoch 40/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 0.3468
# Epoch 00040: val_loss did not improve from 1.61240
# 36000/36000 [==============================] - 7s 195us/sample - loss: 0.3468 - val_loss: 1.6127
# Epoch 41/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 0.3199
# Epoch 00041: val_loss did not improve from 1.61240
# 36000/36000 [==============================] - 7s 195us/sample - loss: 0.3198 - val_loss: 1.6279
# Epoch 42/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 0.2935
# Epoch 00042: val_loss did not improve from 1.61240
# 36000/36000 [==============================] - 7s 195us/sample - loss: 0.2938 - val_loss: 1.6263
# Epoch 43/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 0.2716
# Epoch 00043: val_loss did not improve from 1.61240
# 36000/36000 [==============================] - 7s 195us/sample - loss: 0.2717 - val_loss: 1.6333
# Epoch 44/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 0.2507
# Epoch 00044: val_loss did not improve from 1.61240
# 36000/36000 [==============================] - 7s 195us/sample - loss: 0.2507 - val_loss: 1.6460
# Epoch 45/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 0.2318
# Epoch 00045: val_loss did not improve from 1.61240
# 36000/36000 [==============================] - 7s 195us/sample - loss: 0.2320 - val_loss: 1.6486
# Epoch 46/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 0.2146
# Epoch 00046: val_loss did not improve from 1.61240
# 36000/36000 [==============================] - 7s 195us/sample - loss: 0.2146 - val_loss: 1.6538
# Epoch 47/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 0.1994
# Epoch 00047: val_loss did not improve from 1.61240
# 36000/36000 [==============================] - 7s 195us/sample - loss: 0.1994 - val_loss: 1.6507
# Epoch 48/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 0.1875
# Epoch 00048: val_loss did not improve from 1.61240
# 36000/36000 [==============================] - 7s 194us/sample - loss: 0.1877 - val_loss: 1.6850
# Epoch 49/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 0.1733
# Epoch 00049: val_loss did not improve from 1.61240
# 36000/36000 [==============================] - 7s 195us/sample - loss: 0.1733 - val_loss: 1.6738
# Epoch 50/50
# 35840/36000 [============================>.] - ETA: 0s - loss: 0.1645
# Epoch 00050: val_loss did not improve from 1.61240
# 36000/36000 [==============================] - 7s 194us/sample - loss: 0.1645 - val_loss: 1.6803

# %% [markdown]
# ### We also save the final model to check it's performance

# %%
model.save('my_nmt_model.h5')

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['train','validation'])

# %% [markdown]
# # Text Generator
#
# We build a utility function to generate text sequences based on the output prediction sequences

# %%
from tqdm import tqdm
pd.set_option('display.max_colwidth', 500)

eng_idx2word = {v:k for k, v in eng_tokenizer.word_index.items()}

def generate_prediction_texts(pred_seqs, idx2word_map):
  pred_texts = []

  for pred in tqdm(preds):
    temp = []
    for idx in range(len(pred)):
      w = eng_idx2word.get(pred[idx], None)
      if idx > 0:
        if (w == eng_idx2word.get(pred[idx-1], None)) or (w == None):
            temp.append('')
        else:
            temp.append(w)

      else:
        if(w == None):
            temp.append('')
        else:
            temp.append(w)

    pred_texts.append(' '.join(temp))
  return pred_texts

# %% [markdown]
# # Perform Language Translation with Trained Models

# %%
final_model = keras.models.load_model('./my_nmt_model.h5')
min_loss_model = keras.models.load_model('./my_nmt_model_min_loss.h5')

# %% [markdown]
# # Translation on Train Data

# %% [markdown]
# ### Performance of Final Model on Train Data

# %%
model = final_model
pred_probs = model.predict(train_deu_enc.reshape((train_deu_enc.shape[0], train_deu_enc.shape[1])), verbose=1)
preds = [np.argmax(i, axis=1) for i in pred_probs]
# convert predictions into text (English)
pred_texts = generate_prediction_texts(pred_seqs=preds, idx2word_map=eng_idx2word)
pred_df = pd.DataFrame({'source': train_deu, 'target' : train_eng, 'predicted' : pred_texts})
# Out:
# 40000/40000 [==============================] - 13s 319us/sample
# 100%|██████████| 40000/40000 [00:00<00:00, 139748.88it/s]

# %%
pred_df.head(50).T
# Out:
#                                 0   ...                              49
# source     wo sind sie hingegangen  ...  maria ist ein hübsches mädchen
# target        where have they gone  ...           mary is a pretty girl
# predicted  where have they gone     ...         mary is a pretty girl
#
# [3 rows x 50 columns]

# %%
pred_df.iloc[500:550].T
# Out:
#                              500  ...                549
# source     ich habe hausaufgaben  ...  sie sind bestürzt
# target           i have homework  ...        youre upset
# predicted    i have homework      ...  theyre upset
#
# [3 rows x 50 columns]

# %% [markdown]
# ### Performance of Minimum Loss Model on Train Data

# %%
model = min_loss_model
pred_probs = model.predict(train_deu_enc.reshape((train_deu_enc.shape[0], train_deu_enc.shape[1])), verbose=1)
preds = [np.argmax(i, axis=1) for i in pred_probs]
# convert predictions into text (English)
pred_texts = generate_prediction_texts(pred_seqs=preds, idx2word_map=eng_idx2word)
pred_df = pd.DataFrame({'source': train_deu, 'target' : train_eng, 'predicted' : pred_texts})
# Out:
# 40000/40000 [==============================] - 12s 295us/sample
# 100%|██████████| 40000/40000 [00:00<00:00, 141351.81it/s]

# %%
pred_df.head(50).T
# Out:
#                                 0   ...                              49
# source     wo sind sie hingegangen  ...  maria ist ein hübsches mädchen
# target        where have they gone  ...           mary is a pretty girl
# predicted   where did they gone     ...         mary is a pretty girl
#
# [3 rows x 50 columns]

# %%
pred_df.iloc[500:550].T
# Out:
#                              500  ...                549
# source     ich habe hausaufgaben  ...  sie sind bestürzt
# target           i have homework  ...        youre upset
# predicted    i have homework      ...  theyre upset
#
# [3 rows x 50 columns]

# %% [markdown]
# # Translation on Test Data

# %% [markdown]
# ### Performance of Final Model on Test Data

# %%
model = final_model
pred_probs = model.predict(test_deu_enc.reshape((test_deu_enc.shape[0], test_deu_enc.shape[1])), verbose=1)
preds = [np.argmax(i, axis=1) for i in pred_probs]
# convert predictions into text (English)
pred_texts = generate_prediction_texts(pred_seqs=preds, idx2word_map=eng_idx2word)
pred_df = pd.DataFrame({'source': test_deu, 'target' : test_eng, 'predicted' : pred_texts})
# Out:
# 10000/10000 [==============================] - 3s 297us/sample
# 100%|██████████| 10000/10000 [00:00<00:00, 135825.03it/s]

# %%
pred_df.head(50).T
# Out:
#                              0   ...                     49
# source     du bist zu großzügig  ...  warnung vor dem hunde
# target       youre too generous  ...      beware of the dog
# predicted      youre quite       ...      hold the dogs
#
# [3 rows x 50 columns]

# %%
pred_df.iloc[500:550].T
# Out:
#                                  500  ...             549
# source     ich kann es selbst machen  ...       küss mich
# target            i can do it myself  ...  give me a kiss
# predicted             i can do it     ...    do call
#
# [3 rows x 50 columns]

# %% [markdown]
# ### Performance of Minimum Loss Model on Test Data

# %%
model = min_loss_model
pred_probs = model.predict(test_deu_enc.reshape((test_deu_enc.shape[0], test_deu_enc.shape[1])), verbose=1)
preds = [np.argmax(i, axis=1) for i in pred_probs]
# convert predictions into text (English)
pred_texts = generate_prediction_texts(pred_seqs=preds, idx2word_map=eng_idx2word)
pred_df = pd.DataFrame({'source': test_deu, 'target' : test_eng, 'predicted' : pred_texts})
# Out:
# 10000/10000 [==============================] - 3s 301us/sample
# 100%|██████████| 10000/10000 [00:00<00:00, 134817.40it/s]

# %%
pred_df.head(50).T
# Out:
#                              0   ...                      49
# source     du bist zu großzügig  ...   warnung vor dem hunde
# target       youre too generous  ...       beware of the dog
# predicted      youre grown       ...  roll the hands well
#
# [3 rows x 50 columns]

# %%
pred_df.iloc[500:550].T
# Out:
#                                  500  ...              549
# source     ich kann es selbst machen  ...        küss mich
# target            i can do it myself  ...   give me a kiss
# predicted             i can do it     ...  are help to
#
# [3 rows x 50 columns]
